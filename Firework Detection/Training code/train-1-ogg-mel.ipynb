# %%
import os
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Conv1D, MaxPooling1D, GlobalAveragePooling1D, Flatten
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.optimizers import Adam
import librosa 
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten
from tensorflow.keras.layers import Convolution1D, MaxPooling1D

# Define the path for your 1 second audio files
fireworks_dir = "D:/scriptie/sensor_analysis/CNN-training/data/fireworks1-ogg"
rain_dir = "D:/scriptie/sensor_analysis/CNN-training/data/rain1-ogg"
wind_dir = "D:/scriptie/sensor_analysis/CNN-training/data/wind1-ogg"

# %%
# Load the data
data = []
labels = []

for f in os.listdir(fireworks_dir):
    sound_clip,sr = librosa.load(os.path.join(fireworks_dir, f))
    mel_spect = librosa.feature.melspectrogram(y=sound_clip, sr=sr, n_fft=2048, hop_length=1024)
    mel_spect = librosa.power_to_db(mel_spect, ref=np.max)
    melspect_processed = np.mean(mel_spect.T,axis=0)
    data.append(melspect_processed)
    labels.append("fireworks")

for f in os.listdir(rain_dir):
    sound_clip,sr = librosa.load(os.path.join(rain_dir, f))
    mel_spect = librosa.feature.melspectrogram(y=sound_clip, sr=sr, n_fft=2048, hop_length=1024)
    mel_spect = librosa.power_to_db(mel_spect, ref=np.max)
    melspect_processed = np.mean(mel_spect.T,axis=0)
    data.append(melspect_processed)
    labels.append("rain")

for f in os.listdir(wind_dir):
    sound_clip,sr = librosa.load(os.path.join(wind_dir, f))
    mel_spect = librosa.feature.melspectrogram(y=sound_clip, sr=sr, n_fft=2048, hop_length=1024)
    mel_spect = librosa.power_to_db(mel_spect, ref=np.max)
    melspect_processed = np.mean(mel_spect.T,axis=0)
    data.append(melspect_processed)
    labels.append("wind")

# %%
# Convert data and labels to numpy arrays
data = np.array(data)
labels = np.array(labels)

# Encode labels to integers
le = LabelEncoder()
y = to_categorical(le.fit_transform(labels))

# %%
data.shape
# Out:
# (730, 128)

# %%
# Split the data into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(data, y, test_size=0.3, random_state=42)

num_labels = 3

# %%
# Build model
model = Sequential()

model.add(Convolution1D(128, 5, padding='same', input_shape=(128, 1)))  # Adjust input shape if necessary
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(MaxPooling1D(pool_size=(8)))
model.add(Convolution1D(128, 5, padding='same'))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Flatten())
model.add(Dense(num_labels))
model.add(Activation('softmax'))

# %%
# Compile the model
model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer='adam')

# %%
# Fit the model
history = model.fit(x_train, y_train, batch_size=10, epochs=100, validation_data=(x_test, y_test))
# Out:
# Epoch 1/100
# 52/52 [==============================] - 3s 15ms/step - loss: 2.8370 - accuracy: 0.3933 - val_loss: 0.9708 - val_accuracy: 0.4703
# Epoch 2/100
# 52/52 [==============================] - 0s 8ms/step - loss: 1.0030 - accuracy: 0.4755 - val_loss: 0.8837 - val_accuracy: 0.5799
# Epoch 3/100
# 52/52 [==============================] - 0s 8ms/step - loss: 0.9248 - accuracy: 0.5284 - val_loss: 0.8914 - val_accuracy: 0.7626
# Epoch 4/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.8493 - accuracy: 0.5832 - val_loss: 0.7214 - val_accuracy: 0.8174
# Epoch 5/100
# 52/52 [==============================] - 0s 8ms/step - loss: 0.7868 - accuracy: 0.6380 - val_loss: 0.7084 - val_accuracy: 0.7991
# Epoch 6/100
# 52/52 [==============================] - 0s 8ms/step - loss: 0.6873 - accuracy: 0.7280 - val_loss: 0.6307 - val_accuracy: 0.8128
# Epoch 7/100
# 52/52 [==============================] - 0s 8ms/step - loss: 0.6192 - accuracy: 0.7436 - val_loss: 0.5627 - val_accuracy: 0.8356
# Epoch 8/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.6476 - accuracy: 0.7358 - val_loss: 0.5332 - val_accuracy: 0.8219
# Epoch 9/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.5458 - accuracy: 0.7984 - val_loss: 0.5005 - val_accuracy: 0.8037
# Epoch 10/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.5584 - accuracy: 0.7710 - val_loss: 0.5313 - val_accuracy: 0.7717
# Epoch 11/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.5177 - accuracy: 0.7769 - val_loss: 0.4525 - val_accuracy: 0.8584
# Epoch 12/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.5207 - accuracy: 0.7808 - val_loss: 0.4443 - val_accuracy: 0.8265
# Epoch 13/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.5042 - accuracy: 0.8023 - val_loss: 0.4424 - val_accuracy: 0.8402
# Epoch 14/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.4700 - accuracy: 0.8160 - val_loss: 0.4200 - val_accuracy: 0.8493
# Epoch 15/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.4542 - accuracy: 0.7984 - val_loss: 0.3995 - val_accuracy: 0.8676
# Epoch 16/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.4549 - accuracy: 0.8219 - val_loss: 0.4416 - val_accuracy: 0.8082
# Epoch 17/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.4355 - accuracy: 0.8297 - val_loss: 0.3861 - val_accuracy: 0.8493
# Epoch 18/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.4320 - accuracy: 0.8415 - val_loss: 0.3894 - val_accuracy: 0.8630
# Epoch 19/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.4677 - accuracy: 0.8219 - val_loss: 0.7195 - val_accuracy: 0.7078
# Epoch 20/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.4533 - accuracy: 0.8160 - val_loss: 0.3765 - val_accuracy: 0.8676
# Epoch 21/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.3545 - accuracy: 0.8650 - val_loss: 0.4067 - val_accuracy: 0.8311
# Epoch 22/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.3655 - accuracy: 0.8493 - val_loss: 0.3484 - val_accuracy: 0.8584
# Epoch 23/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.3632 - accuracy: 0.8611 - val_loss: 0.3467 - val_accuracy: 0.8630
# Epoch 24/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.3954 - accuracy: 0.8434 - val_loss: 0.3367 - val_accuracy: 0.8813
# Epoch 25/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.3879 - accuracy: 0.8552 - val_loss: 0.3654 - val_accuracy: 0.8447
# Epoch 26/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.4156 - accuracy: 0.8376 - val_loss: 0.3528 - val_accuracy: 0.8676
# Epoch 27/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.3962 - accuracy: 0.8395 - val_loss: 0.4272 - val_accuracy: 0.8174
# Epoch 28/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.3879 - accuracy: 0.8376 - val_loss: 0.3328 - val_accuracy: 0.8721
# Epoch 29/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.3591 - accuracy: 0.8552 - val_loss: 0.3938 - val_accuracy: 0.8356
# Epoch 30/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.3688 - accuracy: 0.8493 - val_loss: 0.3614 - val_accuracy: 0.8676
# Epoch 31/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.3784 - accuracy: 0.8493 - val_loss: 0.3477 - val_accuracy: 0.8539
# Epoch 32/100
# 52/52 [==============================] - 1s 10ms/step - loss: 0.4104 - accuracy: 0.8434 - val_loss: 0.3630 - val_accuracy: 0.8767
# Epoch 33/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.3746 - accuracy: 0.8337 - val_loss: 0.3488 - val_accuracy: 0.8539
# Epoch 34/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.3620 - accuracy: 0.8513 - val_loss: 0.4453 - val_accuracy: 0.8037
# Epoch 35/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.3095 - accuracy: 0.8787 - val_loss: 0.3438 - val_accuracy: 0.8858
# Epoch 36/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.4037 - accuracy: 0.8160 - val_loss: 0.3585 - val_accuracy: 0.8721
# Epoch 37/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.3451 - accuracy: 0.8787 - val_loss: 0.3437 - val_accuracy: 0.8493
# Epoch 38/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.3397 - accuracy: 0.8650 - val_loss: 0.3719 - val_accuracy: 0.8311
# Epoch 39/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.3065 - accuracy: 0.8669 - val_loss: 0.3478 - val_accuracy: 0.8493
# Epoch 40/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.3721 - accuracy: 0.8571 - val_loss: 0.3559 - val_accuracy: 0.8721
# Epoch 41/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.3404 - accuracy: 0.8611 - val_loss: 0.3362 - val_accuracy: 0.8721
# Epoch 42/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.2998 - accuracy: 0.8806 - val_loss: 0.3617 - val_accuracy: 0.8539
# Epoch 43/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.2870 - accuracy: 0.8982 - val_loss: 0.3216 - val_accuracy: 0.8858
# Epoch 44/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.3202 - accuracy: 0.8493 - val_loss: 0.3371 - val_accuracy: 0.8904
# Epoch 45/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.3211 - accuracy: 0.8845 - val_loss: 0.3924 - val_accuracy: 0.8539
# Epoch 46/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.2846 - accuracy: 0.8806 - val_loss: 0.3307 - val_accuracy: 0.8904
# Epoch 47/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.3057 - accuracy: 0.8767 - val_loss: 0.4036 - val_accuracy: 0.8402
# Epoch 48/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.2873 - accuracy: 0.8806 - val_loss: 0.3315 - val_accuracy: 0.8858
# Epoch 49/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.2593 - accuracy: 0.9022 - val_loss: 0.3331 - val_accuracy: 0.8858
# Epoch 50/100
# 52/52 [==============================] - 1s 10ms/step - loss: 0.2662 - accuracy: 0.8943 - val_loss: 0.3183 - val_accuracy: 0.8904
# Epoch 51/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.2632 - accuracy: 0.8943 - val_loss: 0.3346 - val_accuracy: 0.8813
# Epoch 52/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.2817 - accuracy: 0.8904 - val_loss: 0.3288 - val_accuracy: 0.8721
# Epoch 53/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.2275 - accuracy: 0.9002 - val_loss: 0.3366 - val_accuracy: 0.8721
# Epoch 54/100
# 52/52 [==============================] - 1s 10ms/step - loss: 0.2740 - accuracy: 0.9002 - val_loss: 0.3313 - val_accuracy: 0.8584
# Epoch 55/100
# 52/52 [==============================] - 1s 10ms/step - loss: 0.2422 - accuracy: 0.9100 - val_loss: 0.3232 - val_accuracy: 0.8858
# Epoch 56/100
# 52/52 [==============================] - 1s 10ms/step - loss: 0.2584 - accuracy: 0.9022 - val_loss: 0.3187 - val_accuracy: 0.8995
# Epoch 57/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.2581 - accuracy: 0.9159 - val_loss: 0.3651 - val_accuracy: 0.8721
# Epoch 58/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.2682 - accuracy: 0.8963 - val_loss: 0.3342 - val_accuracy: 0.8904
# Epoch 59/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.2755 - accuracy: 0.8885 - val_loss: 0.3537 - val_accuracy: 0.8813
# Epoch 60/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.2947 - accuracy: 0.8826 - val_loss: 0.4248 - val_accuracy: 0.8402
# Epoch 61/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.2621 - accuracy: 0.8924 - val_loss: 0.3217 - val_accuracy: 0.8950
# Epoch 62/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.2257 - accuracy: 0.9041 - val_loss: 0.3256 - val_accuracy: 0.8950
# Epoch 63/100
# 52/52 [==============================] - 1s 10ms/step - loss: 0.3456 - accuracy: 0.8630 - val_loss: 0.3337 - val_accuracy: 0.8767
# Epoch 64/100
# 52/52 [==============================] - 0s 10ms/step - loss: 0.2453 - accuracy: 0.8924 - val_loss: 0.3260 - val_accuracy: 0.9178
# Epoch 65/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.1782 - accuracy: 0.9178 - val_loss: 0.3459 - val_accuracy: 0.8721
# Epoch 66/100
# 52/52 [==============================] - 1s 10ms/step - loss: 0.2039 - accuracy: 0.9217 - val_loss: 0.4888 - val_accuracy: 0.8128
# Epoch 67/100
# 52/52 [==============================] - 0s 10ms/step - loss: 0.2063 - accuracy: 0.9178 - val_loss: 0.3252 - val_accuracy: 0.9132
# Epoch 68/100
# 52/52 [==============================] - 1s 10ms/step - loss: 0.1992 - accuracy: 0.9335 - val_loss: 0.3438 - val_accuracy: 0.8813
# Epoch 69/100
# 52/52 [==============================] - 0s 10ms/step - loss: 0.2185 - accuracy: 0.9119 - val_loss: 0.3465 - val_accuracy: 0.9087
# Epoch 70/100
# 52/52 [==============================] - 0s 10ms/step - loss: 0.2251 - accuracy: 0.9002 - val_loss: 0.3513 - val_accuracy: 0.9087
# Epoch 71/100
# 52/52 [==============================] - 1s 11ms/step - loss: 0.2820 - accuracy: 0.9002 - val_loss: 0.3350 - val_accuracy: 0.8858
# Epoch 72/100
# 52/52 [==============================] - 1s 10ms/step - loss: 0.1749 - accuracy: 0.9276 - val_loss: 0.3170 - val_accuracy: 0.9041
# Epoch 73/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.2369 - accuracy: 0.9080 - val_loss: 0.3021 - val_accuracy: 0.9132
# Epoch 74/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.1783 - accuracy: 0.9276 - val_loss: 0.2937 - val_accuracy: 0.9132
# Epoch 75/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.2171 - accuracy: 0.9139 - val_loss: 0.3299 - val_accuracy: 0.9041
# Epoch 76/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.2895 - accuracy: 0.8806 - val_loss: 0.3820 - val_accuracy: 0.8676
# Epoch 77/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.2301 - accuracy: 0.9139 - val_loss: 0.3369 - val_accuracy: 0.9132
# Epoch 78/100
# 52/52 [==============================] - 1s 10ms/step - loss: 0.2310 - accuracy: 0.9159 - val_loss: 0.3364 - val_accuracy: 0.8995
# Epoch 79/100
# 52/52 [==============================] - 1s 10ms/step - loss: 0.2135 - accuracy: 0.9178 - val_loss: 0.3874 - val_accuracy: 0.8767
# Epoch 80/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.1791 - accuracy: 0.9276 - val_loss: 0.3344 - val_accuracy: 0.9041
# Epoch 81/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.2091 - accuracy: 0.9119 - val_loss: 0.3669 - val_accuracy: 0.8676
# Epoch 82/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.2561 - accuracy: 0.9159 - val_loss: 0.3692 - val_accuracy: 0.8813
# Epoch 83/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.2049 - accuracy: 0.9119 - val_loss: 0.4074 - val_accuracy: 0.8813
# Epoch 84/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.1945 - accuracy: 0.9198 - val_loss: 0.3530 - val_accuracy: 0.8950
# Epoch 85/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.2301 - accuracy: 0.9100 - val_loss: 0.3802 - val_accuracy: 0.8904
# Epoch 86/100
# 52/52 [==============================] - 1s 10ms/step - loss: 0.1450 - accuracy: 0.9452 - val_loss: 0.3677 - val_accuracy: 0.9041
# Epoch 87/100
# 52/52 [==============================] - 0s 10ms/step - loss: 0.1705 - accuracy: 0.9374 - val_loss: 0.4502 - val_accuracy: 0.8630
# Epoch 88/100
# 52/52 [==============================] - 1s 10ms/step - loss: 0.1615 - accuracy: 0.9393 - val_loss: 0.3718 - val_accuracy: 0.8858
# Epoch 89/100
# 52/52 [==============================] - 1s 10ms/step - loss: 0.2099 - accuracy: 0.9178 - val_loss: 0.4118 - val_accuracy: 0.8767
# Epoch 90/100
# 52/52 [==============================] - 1s 10ms/step - loss: 0.1820 - accuracy: 0.9315 - val_loss: 0.4072 - val_accuracy: 0.8493
# Epoch 91/100
# 52/52 [==============================] - 1s 10ms/step - loss: 0.2176 - accuracy: 0.9217 - val_loss: 0.3722 - val_accuracy: 0.8995
# Epoch 92/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.1367 - accuracy: 0.9413 - val_loss: 0.3581 - val_accuracy: 0.8995
# Epoch 93/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.1559 - accuracy: 0.9432 - val_loss: 0.3393 - val_accuracy: 0.9041
# Epoch 94/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.1637 - accuracy: 0.9276 - val_loss: 0.3639 - val_accuracy: 0.9132
# Epoch 95/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.1935 - accuracy: 0.9217 - val_loss: 0.3887 - val_accuracy: 0.8813
# Epoch 96/100
# 52/52 [==============================] - 1s 10ms/step - loss: 0.1555 - accuracy: 0.9393 - val_loss: 0.3659 - val_accuracy: 0.9087
# Epoch 97/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.1646 - accuracy: 0.9393 - val_loss: 0.4535 - val_accuracy: 0.8676
# Epoch 98/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.1745 - accuracy: 0.9335 - val_loss: 0.4701 - val_accuracy: 0.8676
# Epoch 99/100
# 52/52 [==============================] - 1s 10ms/step - loss: 0.2011 - accuracy: 0.9178 - val_loss: 0.3824 - val_accuracy: 0.9087
# Epoch 100/100
# 52/52 [==============================] - 1s 10ms/step - loss: 0.1490 - accuracy: 0.9452 - val_loss: 0.3879 - val_accuracy: 0.9087

# %%
loss, accuracy = model.evaluate(x_test, y_test)
print(f"Test set accuracy: {accuracy * 100}%")
# Out:
# 7/7 [==============================] - 0s 26ms/step - loss: 0.3879 - accuracy: 0.9087
# Test set accuracy: 90.86757898330688%

# %%
import matplotlib.pyplot as plt

# Plot training & validation accuracy values
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')

# Plot training & validation loss values
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')

plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns

# Make predictions
predictions_prob = model.predict(x_test)

# Convert predictions classes to one hot vectors 
predictions = np.argmax(predictions_prob, axis=1) 

# Convert test set labels to one hot vectors
y_test_classes = np.argmax(y_test, axis=1)

from sklearn.metrics import classification_report
print(classification_report(y_test_classes, predictions))

# Compute confusion matrix
cm = confusion_matrix(y_test_classes, predictions)

# Plot confusion matrix
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.show()
# Out:
# 7/7 [==============================] - 0s 3ms/step
#               precision    recall  f1-score   support
#
#            0       0.98      0.88      0.93       104
#            1       0.85      0.92      0.88        66
#            2       0.87      0.94      0.90        49
#
#     accuracy                           0.91       219
#    macro avg       0.90      0.92      0.91       219
# weighted avg       0.91      0.91      0.91       219

# %%
# Save the model
model.save('1-ogg-mel.h5')
