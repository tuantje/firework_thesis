# %%
import os
import librosa  # for audio processing
import numpy as np
from sklearn.model_selection import train_test_split

# directories for wav files
dirs = [
    "D:\\scriptie\\sensor_analysis\\CNN-training\\data\\fireworks5-ogg",
    "D:\\scriptie\\sensor_analysis\\CNN-training\\data\\rain5-ogg",
    "D:\\scriptie\\sensor_analysis\\CNN-training\\data\\wind5-ogg",
]

# %%
labels = []
data = []

# Loop over all files in all directories
for i, dir in enumerate(dirs):
    for filename in os.listdir(dir):
        if filename.endswith(".ogg"):  # check if it's an .ogg file
            # Load the audio file
            audio, sr = librosa.load(os.path.join(dir, filename), res_type='kaiser_fast')

            # Extract MFCCs from the audio
            mfccs = librosa.feature.mfcc(y=audio, sr=sr, n_mfcc=40)
            mfccs_processed = np.mean(mfccs.T,axis=0)
            
            # Add the MFCCs to the data list
            data.append(mfccs_processed)

            # Add the label (i.e., the directory index) to the labels list
            labels.append(i)

# %%
# Convert data and labels lists to numpy arrays
data = np.array(data)
labels = np.array(labels)

# Split data into training and test sets
x_train, x_test, y_train, y_test = train_test_split(data, labels, test_size=0.3, random_state=42)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten
from tensorflow.keras.layers import Convolution1D, MaxPooling1D

# number of labels
num_labels = len(dirs)

# %%
# Build model
model = Sequential()

model.add(Convolution1D(128, 5, padding='same', input_shape=(40, 1)))  # Adjust input shape if necessary
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(MaxPooling1D(pool_size=(8)))
model.add(Convolution1D(128, 5, padding='same'))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Flatten())
model.add(Dense(num_labels))
model.add(Activation('softmax'))

# %%
model.compile(loss='sparse_categorical_crossentropy', metrics=['accuracy'], optimizer='adam')

# %%
history = model.fit(x_train, y_train, batch_size=10, epochs=100, validation_data=(x_test, y_test))
# Out:
# Epoch 1/100
# 11/11 [==============================] - 2s 39ms/step - loss: 5.4410 - accuracy: 0.4412 - val_loss: 1.3364 - val_accuracy: 0.5000
# Epoch 2/100
# 11/11 [==============================] - 0s 12ms/step - loss: 5.1431 - accuracy: 0.5882 - val_loss: 0.9161 - val_accuracy: 0.6818
# Epoch 3/100
# 11/11 [==============================] - 0s 11ms/step - loss: 3.7529 - accuracy: 0.6765 - val_loss: 0.9650 - val_accuracy: 0.7273
# Epoch 4/100
# 11/11 [==============================] - 0s 12ms/step - loss: 3.3578 - accuracy: 0.6078 - val_loss: 1.0817 - val_accuracy: 0.7045
# Epoch 5/100
# 11/11 [==============================] - 0s 12ms/step - loss: 2.7136 - accuracy: 0.6961 - val_loss: 0.6803 - val_accuracy: 0.7500
# Epoch 6/100
# 11/11 [==============================] - 0s 12ms/step - loss: 2.9148 - accuracy: 0.5980 - val_loss: 0.9634 - val_accuracy: 0.7500
# Epoch 7/100
# 11/11 [==============================] - 0s 12ms/step - loss: 1.3436 - accuracy: 0.7843 - val_loss: 0.3880 - val_accuracy: 0.7955
# Epoch 8/100
# 11/11 [==============================] - 0s 12ms/step - loss: 2.3843 - accuracy: 0.6961 - val_loss: 1.4534 - val_accuracy: 0.7045
# Epoch 9/100
# 11/11 [==============================] - 0s 12ms/step - loss: 1.4264 - accuracy: 0.6863 - val_loss: 0.4942 - val_accuracy: 0.7727
# Epoch 10/100
# 11/11 [==============================] - 0s 12ms/step - loss: 1.5743 - accuracy: 0.7451 - val_loss: 1.0051 - val_accuracy: 0.7500
# Epoch 11/100
# 11/11 [==============================] - 0s 12ms/step - loss: 1.4150 - accuracy: 0.7157 - val_loss: 0.3806 - val_accuracy: 0.9091
# Epoch 12/100
# 11/11 [==============================] - 0s 13ms/step - loss: 1.1213 - accuracy: 0.7451 - val_loss: 0.4562 - val_accuracy: 0.8409
# Epoch 13/100
# 11/11 [==============================] - 0s 12ms/step - loss: 0
100
# 11/11 [==============================] - 0s 12ms/step - loss: 0.2959 - accuracy: 0.8824 - val_loss: 0.2479 - val_accuracy: 0.9318
# Epoch 64/100
# 11/11 [==============================] - 0s 14ms/step - loss: 0.3004 - accuracy: 0.8725 - val_loss: 0.2474 - val_accuracy: 0.9545
# Epoch 65/100
# 11/11 [==============================] - 0s 13ms/step - loss: 0.2609 - accuracy: 0.9118 - val_loss: 0.3181 - val_accuracy: 0.9318
# Epoch 66/100
# 11/11 [==============================] - 0s 12ms/step - loss: 0.3461 - accuracy: 0.8627 - val_loss: 0.2674 - val_accuracy: 0.9545
# Epoch 67/100
# 11/11 [==============================] - 0s 11ms/step - loss: 0.2257 - accuracy: 0.9510 - val_loss: 0.2626 - val_accuracy: 0.9318
# Epoch 68/100
# 11/11 [==============================] - 0s 14ms/step - loss: 0.2680 - accuracy: 0.9118 - val_loss: 0.2610 - val_accuracy: 0.9318
# Epoch 69/100
# 11/11 [==============================] - 0s 15ms/step - loss: 0.3440 - accuracy: 0.8725 - val_loss: 0.2518 - val_accuracy: 0.9091
# Epoch 70/100
# 11/11 [==============================] - 0s 13ms/step - loss: 0.2496 - accuracy: 0.9020 - val_loss: 0.2396 - val_accuracy: 0.9091
# Epoch 71/100
# 11/11 [==============================] - 0s 12ms/step - loss: 0.2404 - accuracy: 0.9314 - val_loss: 0.2947 - val_accuracy: 0.9091
# Epoch 72/100
# 11/11 [==============================] - 0s 13ms/step - loss: 0.2843 - accuracy: 0.8627 - val_loss: 0.2854 - val_accuracy: 0.9318
# Epoch 73/100
# 11/11 [==============================] - 0s 12ms/step - loss: 0.2220 - accuracy: 0.9314 - val_loss: 0.3213 - val_accuracy: 0.9091
# Epoch 74/100
# 11/11 [==============================] - 0s 12ms/step - loss: 0.2197 - accuracy: 0.9020 - val_loss: 0.2470 - val_accuracy: 0.9091
# Epoch 75/100
# 11/11 [==============================] - 0s 13ms/step - loss: 0.2752 - accuracy: 0.9020 - val_loss: 0.2204 - val_accuracy: 0.9318
# Epoch 76/100
# 11/11 [==============================] - 0s 12ms/step - loss: 0.2208 - accuracy: 0.9216 - val_loss: 0.2403 - val_accuracy: 0.9318
# Epoch 77/100
# 11/11 [==============================] - 0s 13ms/step - loss: 0.1860 - accuracy: 0.9510 - val_loss: 0.2672 - val_accuracy: 0.9091
# Epoch 78/100
# 11/11 [==============================] - 0s 13ms/step - loss: 0.2427 - accuracy: 0.9020 - val_loss: 0.2721 - val_accuracy: 0.9318
# Epoch 79/100
# 11/11 [==============================] - 0s 12ms/step - loss: 0.2167 - accuracy: 0.9118 - val_loss: 0.3140 - val_accuracy: 0.9091
# Epoch 80/100
# 11/11 [==============================] - 0s 12ms/step - loss: 0.2811 - accuracy: 0.8922 - val_loss: 0.2406 - val_accuracy: 0.9545
# Epoch 81/100
# 11/11 [==============================] - 0s 13ms/step - loss: 0.3360 - accuracy: 0.8922 - val_loss: 0.2532 - val_accuracy: 0.9318
# Epoch 82/100
# 11/11 [==============================] - 0s 13ms/step - loss: 0.1977 - accuracy: 0.9412 - val_loss: 0.2713 - val_accuracy: 0.9318
# Epoch 83/100
# 11/11 [==============================] - 0s 14ms/step - loss: 0.3070 - accuracy: 0.9216 - val_loss: 0.3091 - val_accuracy: 0.9545
# Epoch 84/100
# 11/11 [==============================] - 0s 13ms/step - loss: 0.1452 - accuracy: 0.9510 - val_loss: 0.3285 - val_accuracy: 0.8864
# Epoch 85/100
# 11/11 [==============================] - 0s 13ms/step - loss: 0.2619 - accuracy: 0.8922 - val_loss: 0.3183 - val_accuracy: 0.9318
# Epoch 86/100
# 11/11 [==============================] - 0s 12ms/step - loss: 0.1903 - accuracy: 0.9510 - val_loss: 0.2897 - val_accuracy: 0.9318
# Epoch 87/100
# 11/11 [==============================] - 0s 12ms/step - loss: 0.2550 - accuracy: 0.8922 - val_loss: 0.3141 - val_accuracy: 0.9318
# Epoch 88/100
# 11/11 [==============================] - 0s 12ms/step - loss: 0.2216 - accuracy: 0.9216 - val_loss: 0.2487 - val_accuracy: 0.9318
# Epoch 89/100
# 11/11 [==============================] - 0s 12ms/step - loss: 0.1671 - accuracy: 0.9412 - val_loss: 0.2254 - val_accuracy: 0.9545
# Epoch 90/100
# 11/11 [==============================] - 0s 11ms/step - loss: 0.1513 - accuracy: 0.9510 - val_loss: 0.2673 - val_accuracy: 0.9091
# Epoch 91/100
# 11/11 [==============================] - 0s 11ms/step - loss: 0.1203 - accuracy: 0.9706 - val_loss: 0.2743 - val_accuracy: 0.9091
# Epoch 92/100
# 11/11 [==============================] - 0s 12ms/step - loss: 0.1211 - accuracy: 0.9510 - val_loss: 0.2496 - val_accuracy: 0.9318
# Epoch 93/100
# 11/11 [==============================] - 0s 12ms/step - loss: 0.1594 - accuracy: 0.9412 - val_loss: 0.2858 - val_accuracy: 0.9091
# Epoch 94/100
# 11/11 [==============================] - 0s 12ms/step - loss: 0.1802 - accuracy: 0.9216 - val_loss: 0.3356 - val_accuracy: 0.9091
# Epoch 95/100
# 11/11 [==============================] - 0s 13ms/step - loss: 0.2788 - accuracy: 0.9412 - val_loss: 0.3208 - val_accuracy: 0.8864
# Epoch 96/100
# 11/11 [==============================] - 0s 12ms/step - loss: 0.1885 - accuracy: 0.9314 - val_loss: 0.2228 - val_accuracy: 0.9545
# Epoch 97/100
# 11/11 [==============================] - 0s 12ms/step - loss: 0.2250 - accuracy: 0.9314 - val_loss: 0.2940 - val_accuracy: 0.8864
# Epoch 98/100
# 11/11 [==============================] - 0s 13ms/step - loss: 0.2050 - accuracy: 0.9216 - val_loss: 0.3689 - val_accuracy: 0.9091
# Epoch 99/100
# 11/11 [==============================] - 0s 13ms/step - loss: 0.1317 - accuracy: 0.9412 - val_loss: 0.2756 - val_accuracy: 0.9318
# Epoch 100/100
# 11/11 [==============================] - 0s 12ms/step - loss: 0.2305 - accuracy: 0.8922 - val_loss: 0.2866 - val_accuracy: 0.8864

# %%
loss, accuracy = model.evaluate(x_test, y_test)
print(f"Test set accuracy: {accuracy * 100}%")
# Out:
# 2/2 [==============================] - 0s 33ms/step - loss: 0.2866 - accuracy: 0.8864
# Test set accuracy: 88.63636255264282%

# %%
import matplotlib.pyplot as plt

# Plot training & validation accuracy values
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')

# Plot training & validation loss values
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')

plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns

# Predict class probabilities
y_prob = model.predict(x_test)

# Convert probabilities into class predictions
y_pred = np.argmax(y_prob, axis=1)

# Print classification report
print(classification_report(y_test, y_pred))

# Compute confusion matrix
cm = confusion_matrix(y_test, y_pred)

# Plot confusion matrix
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.show()
# Out:
# 2/2 [==============================] - 0s 4ms/step
#               precision    recall  f1-score   support
#
#            0       0.84      1.00      0.91        21
#            1       0.90      0.90      0.90        10
#            2       1.00      0.69      0.82        13
#
#     accuracy                           0.89        44
#    macro avg       0.91      0.86      0.88        44
# weighted avg       0.90      0.89      0.88        44

# %%
# Save the entire model as a SavedModel.
model.save('my_model-5-ogg-mfcc')
# Save the entire model to a HDF5 file.
model.save('my_model-5-ogg-mfcc.h5')
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: my_model-5-ogg-mfcc\assets
# INFO:tensorflow:Assets written to: my_model-5-ogg-mfcc\assets

# %%
# Out:
# ['C:/Users/MSI/OneDrive/Bureaublad/confusion matrix\\1-sec-ogg-mel.png', 'C:/Users/MSI/OneDrive/Bureaublad/confusion matrix\\1-sec-ogg-mfcc.png', 'C:/Users/MSI/OneDrive/Bureaublad/confusion matrix\\1-sec-wav-mel.png', 'C:/Users/MSI/OneDrive/Bureaublad/confusion matrix\\1-sec-wav-mfcc.png', 'C:/Users/MSI/OneDrive/Bureaublad/confusion matrix\\5-sec-ogg-mel.png', 'C:/Users/MSI/OneDrive/Bureaublad/confusion matrix\\5-sec-ogg-mfcc.png', 'C:/Users/MSI/OneDrive/Bureaublad/confusion matrix\\5-sec-wav-mel.png', 'C:/Users/MSI/OneDrive/Bureaublad/confusion matrix\\5-sec-wav-mfcc.png']
